# %%
import pyodbc
import pandas as pd
import numpy as np
import os

# %%
final_df = pd.DataFrame()

# %%
final_fl_dict = pd.DataFrame()
final_ag_dict = pd.DataFrame()
final_comm_dict = pd.DataFrame()

# %%
conn_lims = pyodbc.connect("Driver={SQL Server};"
                        "Server=192.168.5.18\CROPNUT;"
                        "Database=cropnuts;"
                        "uid=thomasTsuma;pwd=GR^KX$uRe9#JwLc6")

# %%
settings = pd.read_csv("Settings.csv")

# %%
settings
# Out:
#      Unnamed: 0  use_nutrient_req  use_YieldvsSoilTestRanges  crop_code  \
# 0             0             False                       True        194
# 1             1             False                       True        194
# 2             2             False                       True         23
# 3             3             False                       True         46
# 4             4             False                       True         46
# ..          ...               ...                        ...        ...
# 188          62             False                      False         23
# 189          97             False                       True         69
# 190          98             False                       True         69
# 191         204             False                       True        702
# 192         253             False                       True       1112
#
#      chemical_code  client_id  farm_code chemical_symbol         crop_name  \
# 0               19       7669          0               P            Millet
# 1               19       7670          0               P            Millet
# 2               19       7669          0               P                ma
# 3               19       8763          0               P             Maize
# 4               19       7669          0               P             Maize
# ..             ...        ...        ...             ...               ...
# 188             19        293       6822               P                ma
# 189             19       5528          0               P           Tobacco
# 190              1       5528          0               K           Tobacco
# 191             19       6598          0               P  Potatoes (Irish)
# 192             19        577          0               P    Maize (Silage)
#
#         farm_name         client_name client_type
# 0             NaN    OCP_Nigeria1- NW    farm_lab
# 1             NaN         OCP_Ghana_1    farm_lab
# 2             NaN    OCP_Nigeria1- NW    farm_lab
# 3             NaN  OCP_Nigeria3-SS/SE    farm_lab
# 4             NaN    OCP_Nigeria1- NW    farm_lab
# ..            ...                 ...         ...
# 188  Erasto Oraro                 NaN  Commercial
# 189           NaN                 NaN  Commercial
# 190           NaN                 NaN  Commercial
# 191           NaN                 NaN  Commercial
# 192           NaN                 NaN  Commercial
#
# [193 rows x 12 columns]

# %%
potassium_master_req = pd.read_csv("Nutrient_Requirement/Potassium_req_df.csv")

# %%
potassium_master_req = potassium_master_req.drop("Unnamed: 0", axis=1)

# %%
potassium_master_req.columns.to_list()
# Out:
# ['upper_bound',
#  'units',
#  'symbol',
#  'start',
#  'lower_bound',
#  'interval',
#  'end',
#  'Range',
#  'Option_Status',
#  'Nutrient_Req_Id',
#  'Crop_Name',
#  'Crop_Code',
#  'Client_Id',
#  'Chemical_code',
#  'Chemical_Name',
#  '95',
#  '90',
#  '9.5',
#  '9',
#  '85',
#  '80',
#  '8.5',
#  '8',
#  '750',
#  '75',
#  '70',
#  '7.5',
#  '7',
#  '65',
#  '60',
#  '6.5',
#  '6',
#  '55',
#  '500',
#  '50',
#  '5.5',
#  '5',
#  '45',
#  '44',
#  '43',
#  '42',
#  '41',
#  '40',
#  '4.9',
#  '4.85',
#  '4.8',
#  '4.75',
#  '4.7',
#  '4.6',
#  '4.5',
#  '4.4',
#  '4.35',
#  '4.3',
#  '4.25',
#  '4.2',
#  '4.1',
#  '4',
#  '39',
#  '38',
#  '37',
#  '36',
#  '35',
#  '34',
#  '33',
#  '32',
#  '31',
#  '30',
#  '3.9',
#  '3.85',
#  '3.8',
#  '3.75',
#  '3.7',
#  '3.6',
#  '3.5',
#  '3.4',
#  '3.35',
#  '3.3',
#  '3.25',
#  '3.2',
#  '3.1',
#  '3',
#  '29',
#  '28',
#  '27',
#  '26',
#  '25',
#  '24',
#  '23',
#  '22',
#  '21',
#  '20',
#  '2.9',
#  '2.85',
#  '2.8',
#  '2.75',
#  '2.7',
#  '2.6',
#  '2.5',
#  '2.4',
#  '2.35',
#  '2.3',
#  '2.25',
#  '2.2',
#  '2.1',
#  '2',
#  '19.5',
#  '19',
#  '18.5',
#  '18',
#  '17.5',
#  '17',
#  '16.5',
#  '16',
#  '1500',
#  '15.5',
#  '15',
#  '140',
#  '14.5',
#  '14',
#  '130',
#  '13.5',
#  '13',
#  '1250',
#  '120',
#  '12.5',
#  '12',
#  '110',
#  '11.5',
#  '11',
#  '1000',
#  '100',
#  '10.5',
#  '10',
#  '1.9',
#  '1.85',
#  '1.8',
#  '1.75',
#  '1.7',
#  '1.6',
#  '1.5',
#  '1.4',
#  '1.35',
#  '1.3',
#  '1.25',
#  '1.2',
#  '1.1',
#  '1',
#  '0.9',
#  '0.85',
#  '0.8',
#  '0.75',
#  '0.7',
#  '0.6',
#  '0.5',
#  '0.35',
#  '0.1',
#  '0']

# %%
cols = [*potassium_master_req.columns.to_list()[15:], *["Client_Id","Crop_Name","Chemical_Name","Crop_Code"]]

# %%
print(cols)
# Out:
# ['95', '90', '9.5', '9', '85', '80', '8.5', '8', '750', '75', '70', '7.5', '7', '65', '60', '6.5', '6', '55', '500', '50', '5.5', '5', '45', '44', '43', '42', '41', '40', '4.9', '4.85', '4.8', '4.75', '4.7', '4.6', '4.5', '4.4', '4.35', '4.3', '4.25', '4.2', '4.1', '4', '39', '38', '37', '36', '35', '34', '33', '32', '31', '30', '3.9', '3.85', '3.8', '3.75', '3.7', '3.6', '3.5', '3.4', '3.35', '3.3', '3.25', '3.2', '3.1', '3', '29', '28', '27', '26', '25', '24', '23', '22', '21', '20', '2.9', '2.85', '2.8', '2.75', '2.7', '2.6', '2.5', '2.4', '2.35', '2.3', '2.25', '2.2', '2.1', '2', '19.5', '19', '18.5', '18', '17.5', '17', '16.5', '16', '1500', '15.5', '15', '140', '14.5', '14', '130', '13.5', '13', '1250', '120', '12.5', '12', '110', '11.5', '11', '1000', '100', '10.5', '10', '1.9', '1.85', '1.8', '1.75', '1.7', '1.6', '1.5', '1.4', '1.35', '1.3', '1.25', '1.2', '1.1', '1', '0.9', '0.85', '0.8', '0.75', '0.7', '0.6', '0.5', '0.35', '0.1', '0', 'Client_Id', 'Crop_Name', 'Chemical_Name', 'Crop_Code']

# %%
potassium_master_req = potassium_master_req[cols]

# %%
potassium_master_req
# Out:
#      95  90  9.5   9  85  80  8.5   8  750  75  ...  0.7  0.6  0.5  0.35  0.1  \
# 0   NaN NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN  NaN   NaN  NaN
# 1   NaN NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN  NaN   NaN  NaN
# 2   NaN NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN  NaN   NaN  NaN
# 3   NaN NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN  NaN   NaN  NaN
# 4   NaN NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN  NaN   NaN  NaN
# ..   ..  ..  ...  ..  ..  ..  ...  ..  ...  ..  ...  ...  ...  ...   ...  ...
# 532 NaN NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN  NaN   NaN  NaN
# 533 NaN NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN  NaN   NaN  NaN
# 534 NaN NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN  NaN   NaN  NaN
# 535 NaN NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN  NaN   NaN  NaN
# 536 NaN NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN  NaN   NaN  NaN
#
#       0  Client_Id                     Crop_Name  Chemical_Name  Crop_Code
# 0   NaN          0                    Baby Corns      Potassium         13
# 1   NaN          0                    Baby Corns      Potassium         13
# 2   NaN          0                    Baby Corns      Potassium         13
# 3   NaN          0                    Baby Corns      Potassium         13
# 4   NaN          0                    Baby Corns      Potassium         13
# ..   ..        ...                           ...            ...        ...
# 532 NaN          0  Soya Mix SM12 >S no Chlorine      Potassium       1538
# 533 NaN          0  Soya Mix SM12 >S no Chlorine      Potassium       1538
# 534 NaN          0  Soya Mix SM12 >S no Chlorine      Potassium       1538
# 535 NaN          0  Soya Mix SM12 >S no Chlorine      Potassium       1538
# 536 NaN          0  Soya Mix SM12 >S no Chlorine      Potassium       1538
#
# [537 rows x 146 columns]

# %%
phosphorous_master_req = pd.read_csv("Nutrient_Requirement/Phosphorous_req_df.csv")

# %%
phosphorous_master_req = phosphorous_master_req.drop("Unnamed: 0", axis=1)

# %%
cols = [*phosphorous_master_req.columns.to_list()[15:], *["Client_Id","Crop_Name","Chemical_Name","Crop_Code"]]

# %%
phosphorous_master_req = phosphorous_master_req[cols]

# %%
phosphorous_master_req
# Out:
#      95  90  9.5   9  85  80  8.5      8  750  75  ...  0.9  0.8  0.75  0.7  \
# 0   NaN NaN  NaN NaN NaN NaN  NaN  146.0  NaN NaN  ...  NaN  NaN   NaN  NaN
# 1   NaN NaN  NaN NaN NaN NaN  NaN  122.0  NaN NaN  ...  NaN  NaN   NaN  NaN
# 2   NaN NaN  NaN NaN NaN NaN  NaN   98.0  NaN NaN  ...  NaN  NaN   NaN  NaN
# 3   NaN NaN  NaN NaN NaN NaN  NaN    0.0  NaN NaN  ...  NaN  NaN   NaN  NaN
# 4   NaN NaN  NaN NaN NaN NaN  NaN    0.0  NaN NaN  ...  NaN  NaN   NaN  NaN
# ..   ..  ..  ...  ..  ..  ..  ...    ...  ...  ..  ...  ...  ...   ...  ...
# 415 NaN NaN  NaN NaN NaN NaN  NaN    NaN  NaN NaN  ...  NaN  NaN   NaN  NaN
# 416 NaN NaN  NaN NaN NaN NaN  NaN    NaN  NaN NaN  ...  NaN  NaN   NaN  NaN
# 417 NaN NaN  NaN NaN NaN NaN  NaN    NaN  NaN NaN  ...  NaN  NaN   NaN  NaN
# 418 NaN NaN  NaN NaN NaN NaN  NaN    NaN  NaN NaN  ...  NaN  NaN   NaN  NaN
# 419 NaN NaN  NaN NaN NaN NaN  NaN    NaN  NaN NaN  ...  NaN  NaN   NaN  NaN
#
#      0.6  0.5  Client_Id                     Crop_Name  Chemical_Name  \
# 0    NaN  NaN          0                         Wheat    Phosphorous
# 1    NaN  NaN          0                         Wheat    Phosphorous
# 2    NaN  NaN          0                         Wheat    Phosphorous
# 3    NaN  NaN          0                         Wheat    Phosphorous
# 4    NaN  NaN          0                         Wheat    Phosphorous
# ..   ...  ...        ...                           ...            ...
# 415  NaN  NaN          0  Soya Mix SM12 >S no Chlorine    Phosphorous
# 416  NaN  NaN          0  Soya Mix SM12 >S no Chlorine    Phosphorous
# 417  NaN  NaN          0  Soya Mix SM12 >S no Chlorine    Phosphorous
# 418  NaN  NaN          0  Soya Mix SM12 >S no Chlorine    Phosphorous
# 419  NaN  NaN          0  Soya Mix SM12 >S no Chlorine    Phosphorous
#
#      Crop_Code
# 0           18
# 1           18
# 2           18
# 3           18
# 4           18
# ..         ...
# 415       1538
# 416       1538
# 417       1538
# 418       1538
# 419       1538
#
# [420 rows x 132 columns]

# %%
fl = settings.loc[settings['client_type'] == 'farm_lab']
crop_fl_settings_dict = {}
for code in fl.crop_code.values:
    if(code in crop_fl_settings_dict.keys()):
        continue
    ct = len(fl.loc[(fl['crop_code'] == code) & (fl['use_YieldvsSoilTestRanges'] == True)])
    crop_fl_settings_dict[code] = ct
final_fl_dict['crop_code'] = crop_fl_settings_dict.keys()
final_fl_dict['InstancesUseYieldVsSoilTestRange'] = crop_fl_settings_dict.values()
final_fl_dict['Client_Type'] = 'FarmLab'

# %%
comm = settings.loc[settings['client_type'] == 'Commercial']
crop_comm_settings_dict = {}
for code in comm.crop_code.values:
    if(code in crop_comm_settings_dict.keys()):
        continue
    ct = len(comm.loc[(comm['crop_code'] == code) & (comm['use_YieldvsSoilTestRanges'] == True)])
    crop_comm_settings_dict[code] = ct
final_comm_dict['crop_code'] = crop_comm_settings_dict.keys()
final_comm_dict['InstancesUseYieldVsSoilTestRange'] = crop_comm_settings_dict.values()
final_comm_dict['Client_Type'] = 'Commercial'

# %%
ct

# %%
settings.client_type.unique()

# %%
ag = settings.loc[settings['client_type'] == 'AgViza']
crop_ag_settings_dict = {}
for code in ag.crop_code.values:
    if(code in crop_ag_settings_dict.keys()):
        continue
    ct = len(ag.loc[(ag['crop_code'] == code) & (ag['use_YieldvsSoilTestRanges'] == True)])
    crop_ag_settings_dict[code] = ct
final_ag_dict['crop_code'] = crop_ag_settings_dict.keys()
final_ag_dict['InstancesUseYieldVsSoilTestRange'] = crop_ag_settings_dict.values()
final_ag_dict['Client_Type'] = 'AgViza'

# %%
final_fl_dict

# %%
settings.columns
# Out:
# Index(['Unnamed: 0', 'use_nutrient_req', 'use_YieldvsSoilTestRanges',
#        'crop_code', 'chemical_code', 'client_id', 'farm_code',
#        'chemical_symbol', 'crop_name', 'farm_name', 'client_name',
#        'client_type'],
#       dtype='object')

# %%
fl_phosphorous = settings.loc[(settings['client_type'] == 'farm_lab') & (settings['use_YieldvsSoilTestRanges']==True) & (settings['chemical_code']==19)]
comm_phosphorous = settings.loc[(settings['client_type'] == 'Commercial') & (settings['use_YieldvsSoilTestRanges']==True) & (settings['chemical_code']==19)]
ag_phosphorous = settings.loc[(settings['client_type'] == 'AgViza') & (settings['use_YieldvsSoilTestRanges']==True) & (settings['chemical_code']==19)]

# %%
fl_potassium = settings.loc[(settings['client_type'] == 'farm_lab') & (settings['use_YieldvsSoilTestRanges']==True) & (settings['chemical_code']==1)]
comm_potassium = settings.loc[(settings['client_type'] == 'Commercial') & (settings['use_YieldvsSoilTestRanges']==True) & (settings['chemical_code']==1)]
ag_potassium = settings.loc[(settings['client_type'] == 'AgViza') & (settings['use_YieldvsSoilTestRanges']==True) & (settings['chemical_code']==1)]

# %% [markdown]
# Analysis for Phosphorous

# %%
final_fl_dict['Chemical_Code'] = 19
for code, cid in zip(fl_phosphorous.crop_code, fl_phosphorous.client_id):
    print(code)
    print(cid)
    similar = False
    df = pd.read_sql(f"SET NOCOUNT ON;execute [load_YieldvsSoilTestRanges] @crop_code={code},@Chemical_code=19,@client_id={cid}", con=conn_lims)
    master = pd.read_sql(f"SET NOCOUNT ON;execute [load_YieldvsSoilTestRanges] @crop_code={code},@Chemical_code=19,@client_id=0", con=conn_lims)
    df = df[df.columns.to_list()[11:]]
    master = master[master.columns.to_list()[11:]]
    print(len(df.columns))
    print(len(master.columns))
    if(len(df.columns) != len(master.columns)):
        continue
    for i in df.columns:
        if(i not in master.columns):
            similar=False
            break
        if(df[i].to_list() == master[i].to_list()):
            similar = True
            continue
        else:
            similar = False
            break
    if(similar == True):
        final_fl_dict.loc[final_fl_dict['crop_code'] == code,'SimilarToMaster'] = True
    else:
        final_fl_dict.loc[final_fl_dict['crop_code'] == code,'SimilarToMaster'] = False

# %%
final_fl_dict

# %%
final_ag_dict['Chemical_Code'] = 19
for code, cid in zip(ag.crop_code, ag.client_id):
    print(code)
    print(cid)
    similar = False
    df = pd.read_sql(f"SET NOCOUNT ON;execute [load_YieldvsSoilTestRanges] @crop_code={code},@Chemical_code=19,@client_id={cid}", con=conn_lims)
    master = pd.read_sql(f"SET NOCOUNT ON;execute [load_YieldvsSoilTestRanges] @crop_code={code},@Chemical_code=19,@client_id=0", con=conn_lims)
    df = df[df.columns.to_list()[11:]]
    master = master[master.columns.to_list()[11:]]
    print(len(df.columns))
    print(len(master.columns))
    if(len(df.columns) != len(master.columns)):
        continue
    for i in df.columns:
        if(i not in master.columns):
            similar=False
            break
        if(df[i].to_list() == master[i].to_list()):
            similar = True
            continue
        else:
            similar = False
            break
    print(similar)
    if(similar == True):
        final_ag_dict.loc[final_ag_dict['crop_code'] == code,'SimilarToMaster'] = True
    else:
        final_ag_dict.loc[final_ag_dict['crop_code'] == code,'SimilarToMaster'] = False

# %%
final_ag_dict

# %%
final_comm_dict['Chemical_Code'] = 19
for code, cid in zip(comm.crop_code, comm.client_id):
    print(code)
    print(cid)
    similar = False
    df = pd.read_sql(f"SET NOCOUNT ON;execute [load_YieldvsSoilTestRanges] @crop_code={code},@Chemical_code=19,@client_id={cid}", con=conn_lims)
    master = pd.read_sql(f"SET NOCOUNT ON;execute [load_YieldvsSoilTestRanges] @crop_code={code},@Chemical_code=19,@client_id=0", con=conn_lims)
    df = df[df.columns.to_list()[11:]]
    master = master[master.columns.to_list()[11:]]
    print(len(df.columns))
    print(len(master.columns))
    if(len(df.columns) != len(master.columns)):
        continue
    for i in df.columns:
        if(i not in master.columns):
            similar=False
            break
        if(df[i].to_list() == master[i].to_list()):
            similar = True
            continue
        else:
            similar = False
            break
    print(similar)
    if(similar == True):
        final_comm_dict.loc[final_comm_dict['crop_code'] == code,'SimilarToMaster'] = True
    else:
        final_comm_dict.loc[final_comm_dict['crop_code'] == code,'SimilarToMaster'] = False

# %%
final_comm_dict

# %% [markdown]
# Analysis for Potassium

# %%
final_fl_dict['Chemical_Code'] = 1
for code, cid in zip(fl.crop_code, fl.client_id):
    print(code)
    print(cid)
    similar = False
    df = pd.read_sql(f"SET NOCOUNT ON;execute [load_YieldvsSoilTestRanges] @crop_code={code},@Chemical_code=1,@client_id={cid}", con=conn_lims)
    master = pd.read_sql(f"SET NOCOUNT ON;execute [load_YieldvsSoilTestRanges] @crop_code={code},@Chemical_code=1,@client_id=0", con=conn_lims)
    df = df[df.columns.to_list()[11:]]
    master = master[master.columns.to_list()[11:]]
    print(len(df.columns))
    print(len(master.columns))
    if(len(df.columns) != len(master.columns)):
        continue
    for i in df.columns:
        if(i not in master.columns):
            similar=False
            break
        if(df[i].to_list() == master[i].to_list()):
            similar = True
            continue
        else:
            similar = False
            break
    if(similar == True):
        final_fl_dict.loc[final_fl_dict['crop_code'] == code,'SimilarToMaster'] = True
    else:
        final_fl_dict.loc[final_fl_dict['crop_code'] == code,'SimilarToMaster'] = False
